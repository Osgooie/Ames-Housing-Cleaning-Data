# %% [markdown]
# <h2 align="center">📋 Dataset Dictionary</h2>
#
# <p align="center">
#   <em>Explore the Ames Housing dataset with this comprehensive guide.</em>
# </p>
#
# <br>
#
# <details>
# <summary><b>📌 Click to expand the full dataset dictionary (82 columns)</b></summary>
#
# <br>
#
# <table align="center" style="width: 100%; border-collapse: collapse; text-align: center; font-size: 13px;">
#
#   <!-- ============================================ -->
#   <!-- 🏠 GENERAL & LOCATION FEATURES -->
#   <!-- ============================================ -->
#
#   <tr style="background-color: #f0f6ff; border-bottom: 3px solid #0366d6;">
#     <th colspan="4" style="padding: 12px; font-size: 18px; color: #0366d6;">🏠 General & Location Features</th>
#   </tr>
#
#   <tr style="background-color: #f6f8fa; font-weight: bold;">
#     <th style="width: 5%; padding: 8px;">#</th>
#     <th style="width: 20%; padding: 8px;">Column</th>
#     <th style="width: 37%; padding: 8px;">Description (English)</th>
#     <th style="width: 38%; padding: 8px;">توضیح (فارسی)</th>
#   </tr>
#
#   <tr><td>1</td><td><b>Order</b></td><td>Sequential order of the record</td><td>شماره ترتیب رکورد در دیتاست</td></tr>
#   <tr><td>2</td><td><b>PID</b></td><td>Unique identifier for each property parcel</td><td>شناسه یکتای هر ملک</td></tr>
#   <tr><td>3</td><td><b>MS SubClass</b></td><td>Building class or type</td><td>نوع یا کلاس ساختمان</td></tr>
#   <tr><td>4</td><td><b>MS Zoning</b></td><td>General zoning classification</td><td>نوع منطقه‌بندی شهری (کاربری زمین)</td></tr>
#   <tr><td>5</td><td><b>Lot Frontage</b></td><td>Linear feet of street frontage</td><td>عرض زمین از سمت خیابان (فوت)</td></tr>
#   <tr><td>6</td><td><b>Lot Area</b></td><td>Total lot size in square feet</td><td>مساحت کل زمین (فوت مربع)</td></tr>
#   <tr><td>7</td><td><b>Street</b></td><td>Type of road access</td><td>نوع خیابان دسترسی</td></tr>
#   <tr><td>8</td><td><b>Alley</b></td><td>Alley access type</td><td>نوع کوچه دسترسی</td></tr>
#   <tr><td>9</td><td><b>Lot Shape</b></td><td>General shape of the property lot</td><td>شکل هندسی زمین</td></tr>
#   <tr><td>10</td><td><b>Land Contour</b></td><td>Flatness or contour level</td><td>وضعیت همواری یا شیب زمین</td></tr>
#   <tr><td>11</td><td><b>Utilities</b></td><td>Available public utilities</td><td>امکانات و خدمات شهری موجود</td></tr>
#   <tr><td>12</td><td><b>Lot Config</b></td><td>Configuration or position of the lot</td><td>نحوه قرارگیری زمین نسبت به خیابان</td></tr>
#   <tr><td>13</td><td><b>Land Slope</b></td><td>Slope inclination level</td><td>میزان شیب زمین</td></tr>
#   <tr><td>14</td><td><b>Neighborhood</b></td><td>Physical location within the city</td><td>محله قرارگیری ملک</td></tr>
#   <tr><td>15</td><td><b>Condition 1</b></td><td>Proximity to main road/railway (1st)</td><td>شرایط محیطی اطراف ملک (اول)</td></tr>
#   <tr><td>16</td><td><b>Condition 2</b></td><td>Proximity to main road/railway (2nd)</td><td>شرایط محیطی اطراف ملک (دوم)</td></tr>
#
#   <!-- ============================================ -->
#   <!-- 🏗️ BUILDING & STRUCTURE FEATURES -->
#   <!-- ============================================ -->
#
#   <tr style="background-color: #f0f6ff; border-bottom: 3px solid #0366d6;">
#     <th colspan="4" style="padding: 12px; font-size: 18px; color: #0366d6;">🏗️ Building & Structure Features</th>
#   </tr>
#
#   <tr style="background-color: #f6f8fa; font-weight: bold;">
#     <th>#</th><th>Column</th><th>Description (English)</th><th>توضیح (فارسی)</th>
#   </tr>
#
#   <tr><td>17</td><td><b>Bldg Type</b></td><td>Type of dwelling structure</td><td>نوع ساختمان</td></tr>
#   <tr><td>18</td><td><b>House Style</b></td><td>Style and number of stories</td><td>سبک یا تعداد طبقات خانه</td></tr>
#   <tr><td>19</td><td><b>Overall Qual</b></td><td>Overall material and finish quality</td><td>کیفیت کلی طراحی و ساخت خانه</td></tr>
#   <tr><td>20</td><td><b>Overall Cond</b></td><td>Current condition and maintenance</td><td>وضعیت کلی و میزان نگهداری ساختمان</td></tr>
#   <tr><td>21</td><td><b>Year Built</b></td><td>Original construction year</td><td>سال ساخت خانه</td></tr>
#   <tr><td>22</td><td><b>Year Remod/Add</b></td><td>Remodeling or addition year</td><td>سال بازسازی یا نوسازی</td></tr>
#   <tr><td>23</td><td><b>Roof Style</b></td><td>Type of roof design</td><td>نوع طراحی سقف</td></tr>
#   <tr><td>24</td><td><b>Roof Matl</b></td><td>Roof covering material</td><td>جنس پوشش سقف</td></tr>
#   <tr><td>25</td><td><b>Exterior 1st</b></td><td>Primary exterior wall covering</td><td>جنس نمای اصلی ساختمان</td></tr>
#   <tr><td>26</td><td><b>Exterior 2nd</b></td><td>Secondary exterior wall covering</td><td>جنس نمای دوم ساختمان</td></tr>
#   <tr><td>27</td><td><b>Mas Vnr Type</b></td><td>Masonry veneer type (stone, brick, etc.)</td><td>نوع نمای تزئینی (سنگ، آجر و ...)</td></tr>
#   <tr><td>28</td><td><b>Mas Vnr Area</b></td><td>Masonry veneer area in sq. ft.</td><td>مساحت نمای تزئینی (فوت مربع)</td></tr>
#   <tr><td>29</td><td><b>Exter Qual</b></td><td>Exterior material quality</td><td>کیفیت نمای بیرونی</td></tr>
#   <tr><td>30</td><td><b>Exter Cond</b></td><td>Exterior material condition</td><td>وضعیت نمای بیرونی</td></tr>
#   <tr><td>31</td><td><b>Foundation</b></td><td>Type of foundation</td><td>نوع فونداسیون ساختمان</td></tr>
#
#   <!-- ============================================ -->
#   <!-- 🏚️ BASEMENT & GARAGE FEATURES -->
#   <!-- ============================================ -->
#
#   <tr style="background-color: #f0f6ff; border-bottom: 3px solid #0366d6;">
#     <th colspan="4" style="padding: 12px; font-size: 18px; color: #0366d6;">🏚️ Basement & Garage Features</th>
#   </tr>
#
#   <tr style="background-color: #f6f8fa; font-weight: bold;">
#     <th>#</th><th>Column</th><th>Description (English)</th><th>توضیح (فارسی)</th>
#   </tr>
#
#   <tr><td>32</td><td><b>Bsmt Qual</b></td><td>Basement quality rating</td><td>کیفیت زیرزمین</td></tr>
#   <tr><td>33</td><td><b>Bsmt Cond</b></td><td>Basement condition status</td><td>وضعیت زیرزمین</td></tr>
#   <tr><td>34</td><td><b>Bsmt Exposure</b></td><td>Walkout or garden level basement exposure</td><td>میزان نورگیری یا دید زیرزمین</td></tr>
#   <tr><td>35</td><td><b>BsmtFin Type 1</b></td><td>First basement finished area type</td><td>نوع تکمیل بخش اول زیرزمین</td></tr>
#   <tr><td>36</td><td><b>BsmtFin SF 1</b></td><td>First basement finished area (sq. ft.)</td><td>مساحت بخش تکمیل‌شده اول زیرزمین</td></tr>
#   <tr><td>37</td><td><b>BsmtFin Type 2</b></td><td>Second basement finished area type</td><td>نوع تکمیل بخش دوم زیرزمین</td></tr>
#   <tr><td>38</td><td><b>BsmtFin SF 2</b></td><td>Second basement finished area (sq. ft.)</td><td>مساحت بخش تکمیل‌شده دوم زیرزمین</td></tr>
#   <tr><td>39</td><td><b>Bsmt Unf SF</b></td><td>Unfinished basement area (sq. ft.)</td><td>مساحت تکمیل‌نشده زیرزمین</td></tr>
#   <tr><td>40</td><td><b>Total Bsmt SF</b></td><td>Total basement area (sq. ft.)</td><td>کل مساحت زیرزمین</td></tr>
#   <tr><td>41</td><td><b>Heating</b></td><td>Type of heating system</td><td>نوع سیستم گرمایشی</td></tr>
#   <tr><td>42</td><td><b>Heating QC</b></td><td>Heating system quality</td><td>کیفیت سیستم گرمایشی</td></tr>
#   <tr><td>43</td><td><b>Central Air</b></td><td>Central air conditioning availability</td><td>وجود سیستم تهویه مطبوع مرکزی</td></tr>
#   <tr><td>44</td><td><b>Electrical</b></td><td>Electrical system type (fuse, breaker, etc.)</td><td>نوع سیستم برق‌کشی</td></tr>
#   <tr><td>60</td><td><b>Garage Type</b></td><td>Garage type (attached, detached, etc.)</td><td>نوع گاراژ</td></tr>
#   <tr><td>61</td><td><b>Garage Yr Blt</b></td><td>Garage construction year</td><td>سال ساخت گاراژ</td></tr>
#   <tr><td>62</td><td><b>Garage Finish</b></td><td>Garage interior finish type</td><td>میزان تکمیل بودن فضای داخلی گاراژ</td></tr>
#   <tr><td>63</td><td><b>Garage Cars</b></td><td>Garage capacity (number of cars)</td><td>ظرفیت گاراژ بر حسب تعداد خودرو</td></tr>
#   <tr><td>64</td><td><b>Garage Area</b></td><td>Garage size in square feet</td><td>مساحت گاراژ</td></tr>
#   <tr><td>65</td><td><b>Garage Qual</b></td><td>Garage quality rating</td><td>کیفیت گاراژ</td></tr>
#   <tr><td>66</td><td><b>Garage Cond</b></td><td>Garage condition status</td><td>وضعیت گاراژ</td></tr>
#   <tr><td>67</td><td><b>Paved Drive</b></td><td>Paved driveway access type</td><td>وضعیت آسفالت بودن مسیر ورودی</td></tr>
#
#   <!-- ============================================ -->
#   <!-- 📐 AREA & ROOM FEATURES -->
#   <!-- ============================================ -->
#
#   <tr style="background-color: #f0f6ff; border-bottom: 3px solid #0366d6;">
#     <th colspan="4" style="padding: 12px; font-size: 18px; color: #0366d6;">📐 Area & Room Features</th>
#   </tr>
#
#   <tr style="background-color: #f6f8fa; font-weight: bold;">
#     <th>#</th><th>Column</th><th>Description (English)</th><th>توضیح (فارسی)</th>
#   </tr>
#
#   <tr><td>45</td><td><b>1st Flr SF</b></td><td>First floor square footage</td><td>مساحت طبقه اول</td></tr>
#   <tr><td>46</td><td><b>2nd Flr SF</b></td><td>Second floor square footage</td><td>مساحت طبقه دوم</td></tr>
#   <tr><td>47</td><td><b>Low Qual Fin SF</b></td><td>Low quality finished square footage</td><td>مساحت فضای تکمیل‌شده با کیفیت پایین</td></tr>
#   <tr><td>48</td><td><b>Gr Liv Area</b></td><td>Above-grade living area (sq. ft.)</td><td>کل فضای قابل سکونت بالای سطح زمین</td></tr>
#   <tr><td>49</td><td><b>Bsmt Full Bath</b></td><td>Full bathrooms in the basement</td><td>تعداد حمام کامل در زیرزمین</td></tr>
#   <tr><td>50</td><td><b>Bsmt Half Bath</b></td><td>Half bathrooms in the basement</td><td>تعداد نیم‌حمام در زیرزمین</td></tr>
#   <tr><td>51</td><td><b>Full Bath</b></td><td>Full bathrooms above grade</td><td>تعداد حمام کامل</td></tr>
#   <tr><td>52</td><td><b>Half Bath</b></td><td>Half bathrooms above grade</td><td>تعداد نیم‌حمام</td></tr>
#   <tr><td>53</td><td><b>Bedroom AbvGr</b></td><td>Bedrooms above grade (excluding basement)</td><td>تعداد اتاق خواب بالای سطح زمین</td></tr>
#   <tr><td>54</td><td><b>Kitchen AbvGr</b></td><td>Kitchens above grade</td><td>تعداد آشپزخانه</td></tr>
#   <tr><td>55</td><td><b>Kitchen Qual</b></td><td>Kitchen quality rating</td><td>کیفیت آشپزخانه</td></tr>
#   <tr><td>56</td><td><b>TotRms AbvGrd</b></td><td>Total rooms above grade (excluding bathrooms)</td><td>تعداد کل اتاق‌های بالای سطح زمین (به جز حمام)</td></tr>
#   <tr><td>57</td><td><b>Functional</b></td><td>Home functionality rating</td><td>وضعیت عملکرد و کارایی خانه</td></tr>
#   <tr><td>58</td><td><b>Fireplaces</b></td><td>Total number of fireplaces</td><td>تعداد شومینه</td></tr>
#   <tr><td>59</td><td><b>Fireplace Qu</b></td><td>Fireplace quality rating</td><td>کیفیت شومینه</td></tr>
#   <tr><td>68</td><td><b>Wood Deck SF</b></td><td>Wood deck area (sq. ft.)</td><td>مساحت تراس یا سکوی چوبی</td></tr>
#   <tr><td>69</td><td><b>Open Porch SF</b></td><td>Open porch area (sq. ft.)</td><td>مساحت ایوان روباز</td></tr>
#   <tr><td>70</td><td><b>Enclosed Porch</b></td><td>Enclosed porch area (sq. ft.)</td><td>مساحت ایوان سرپوشیده</td></tr>
#   <tr><td>71</td><td><b>3Ssn Porch</b></td><td>Three-season porch area (sq. ft.)</td><td>مساحت ایوان سه‌فصل</td></tr>
#   <tr><td>72</td><td><b>Screen Porch</b></td><td>Screen porch area (sq. ft.)</td><td>مساحت ایوان توری‌دار</td></tr>
#   <tr><td>73</td><td><b>Pool Area</b></td><td>Pool area (sq. ft.)</td><td>مساحت استخر</td></tr>
#   <tr><td>74</td><td><b>Pool QC</b></td><td>Pool quality rating</td><td>کیفیت استخر</td></tr>
#   <tr><td>75</td><td><b>Fence</b></td><td>Fence quality or type</td><td>نوع حصار یا نرده ملک</td></tr>
#   <tr><td>76</td><td><b>Misc Feature</b></td><td>Miscellaneous feature (e.g., elevator, workshop)</td><td>سایر امکانات ویژه ملک</td></tr>
#   <tr><td>77</td><td><b>Misc Val</b></td><td>Dollar value of miscellaneous features</td><td>ارزش ریالی امکانات جانبی</td></tr>
#
#   <!-- ============================================ -->
#   <!-- 📅 SALE & TRANSACTION FEATURES -->
#   <!-- ============================================ -->
#
#   <tr style="background-color: #f0f6ff; border-bottom: 3px solid #0366d6;">
#     <th colspan="4" style="padding: 12px; font-size: 18px; color: #0366d6;">📅 Sale & Transaction Features</th>
#   </tr>
#
#   <tr style="background-color: #f6f8fa; font-weight: bold;">
#     <th>#</th><th>Column</th><th>Description (English)</th><th>توضیح (فارسی)</th>
#   </tr>
#
#   <tr><td>78</td><td><b>Mo Sold</b></td><td>Month the property was sold</td><td>ماه فروش ملک</td></tr>
#   <tr><td>79</td><td><b>Yr Sold</b></td><td>Year the property was sold</td><td>سال فروش ملک</td></tr>
#   <tr><td>80</td><td><b>Sale Type</b></td><td>Type of sale transaction</td><td>نوع معامله یا فروش</td></tr>
#   <tr><td>81</td><td><b>Sale Condition</b></td><td>Sale condition (normal, partial, etc.)</td><td>شرایط فروش</td></tr>
#   <tr><td>82</td><td><b>SalePrice</b></td><td>Final sale price (Target Variable)</td><td>قیمت نهایی فروش خانه (متغیر هدف)</td></tr>
#
# </table>
#
# </details>
#
# <br>
#
# <p align="center">
#   <b>📌 Note:</b> This comprehensive dictionary helps you understand every column in the Ames Housing dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../data/AmesHousing.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   str
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   str
#  7   Alley            198 non-null    str
#  8   Lot Shape        2930 non-null   str
#  9   Land Contour     2930 non-null   str
#  10  Utilities        2930 non-null   str
#  11  Lot Config       2930 non-null   str
#  12  Land Slope       2930 non-null   str
#  13  Neighborhood     2930 non-null   str
#  14  Condition 1      2930 non-null   str
#  15  Condition 2      2930 non-null   str
#  16  Bldg Type        2930 non-null   str
#  17  House Style      2930 non-null   str
# ...

# %%
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
plt.boxplot(df["Lot Frontage"])
plt.show()

# %%
df.isna().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
490/2930*100
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df.fillna({"Lot Frontage":df["Lot Frontage"].median()}, inplace=True)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL          68.0      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL          68.0      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df["Has Alley"] = df["Alley"].notna().astype(int)
df["Has Alley"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2925    0
# 2926    0
# 2927    0
# 2928    0
# 2929    0
# Name: Has Alley, Length: 2930, dtype: int64

# %%
has_pool = df[df["Pool QC"].notna()]
no_pool = df[df["Pool QC"].isna()]

print(has_pool["SalePrice"].mean())
print(no_pool["SalePrice"].mean())
print(has_pool["SalePrice"].mean()-no_pool["SalePrice"].mean())
# Out:
# 286036.1538461539
# 180327.04353788137
# 105709.1103082725

# %%
has_fence = df[df["Fence"].notna()]
no_fence = df[df["Fence"].isna()]

print(has_fence["SalePrice"].mean())
print(no_fence["SalePrice"].mean())
print(has_fence["SalePrice"].mean() - no_fence["SalePrice"].mean())
# Out:
# 151352.44055944055
# 187938.44783715013
# -36586.00727770958

# %%
has_Misc_Feature = df[df["Misc Feature"].notna()]
no_Misc_Feature = df[df["Misc Feature"].isna()]

print(has_Misc_Feature["SalePrice"].mean())
print(no_Misc_Feature["SalePrice"].mean())
print(has_Misc_Feature["SalePrice"].mean() - no_Misc_Feature["SalePrice"].mean())
# Out:
# 153992.53773584907
# 181802.14128895185
# -27809.60355310279

# %%
df["Has Pool"] = df["Pool QC"].notna().astype(int)
df["Has Fence"] = df["Fence"].notna().astype(int)
df["Has Misc Feature"] = df["Misc Feature"].notna().astype(int)
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL          68.0      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %%
has_Mas_Vnr_Type_s = df[df["Mas Vnr Type"].notna()]
no_Mas_Vnr_Type_s = df[df["Mas Vnr Type"].isna()]

print(has_Mas_Vnr_Type_s["SalePrice"].mean())
print(no_Misc_Feature["SalePrice"].mean())

print(has_Mas_Vnr_Type_s["SalePrice"].mean()- no_Mas_Vnr_Type_s["SalePrice"].mean())
# Out:
# 219882.26233766234
# 181802.14128895185
# 64519.75923907079

# %%
x = df.groupby("Mas Vnr Type")['SalePrice'].mean().sort_values(ascending=False)
print(x)
# Out:
# Mas Vnr Type
# Stone      260547.297189
# BrkFace    210798.592045
# BrkCmn     140199.000000
# CBlock      80000.000000
# Name: SalePrice, dtype: float64

# %%
df["Mas Vnr Type"].isna().sum()
# Out:
# np.int64(1775)

# %%
df["Mas Vnr Type"].value_counts()
# Out:
# Mas Vnr Type
# BrkFace    880
# Stone      249
# BrkCmn      25
# CBlock       1
# Name: count, dtype: int64

# %%
total_missing_data_Mas_Vnr_Type = df[df["Mas Vnr Type"].isna()]
has_Mas_Vnr_Type = total_missing_data_Mas_Vnr_Type[total_missing_data_Mas_Vnr_Type["Mas Vnr Area"]>0]
no_Mas_Vnr_Type = total_missing_data_Mas_Vnr_Type[total_missing_data_Mas_Vnr_Type["Mas Vnr Area"]==0]

# %%
len(total_missing_data_Mas_Vnr_Type)
# Out:
# 1775

# %%
len(has_Mas_Vnr_Type)
# Out:
# 7

# %%
len(no_Mas_Vnr_Type)
# Out:
# 1745

# %%
area_nan_and_type_nan = df[(df["Mas Vnr Type"].isna()) & (df['Mas Vnr Area'].isna())]
len(area_nan_and_type_nan)
# Out:
# 23

# %%
1745+7+23
# Out:
# 1775

# %%
df.dropna(subset=["Mas Vnr Type","Mas Vnr Area"], how="all",inplace=True) #23

# %%
mask = df['Mas Vnr Type'].isna() & (df['Mas Vnr Area'] > 0) #7
df.loc[mask, 'Mas Vnr Type'] = 'Unknown'

# %%
df["Mas Vnr Type"] = df["Mas Vnr Type"].fillna("None")#1745

# %%
encode = LabelEncoder()
df["Mas Vnr Type Encode"] = encode.fit_transform(df["Mas Vnr Type"])

# %%
unknown_filled =  df[df["Mas Vnr Type"]=="Unknown"] #7
unknown_filled[["Mas Vnr Type","Mas Vnr Area"]]
# Out:
#      Mas Vnr Type  Mas Vnr Area
# 363       Unknown         344.0
# 403       Unknown         312.0
# 441       Unknown         285.0
# 1861      Unknown           1.0
# 1913      Unknown           1.0
# 2003      Unknown           1.0
# 2528      Unknown         288.0

# %%
unknown_filled['Mas Vnr Type'].describe()#7
# Out:
# count           7
# unique          1
# top       Unknown
# freq            7
# Name: Mas Vnr Type, dtype: object

# %%
none_count = (df["Mas Vnr Type"]=="None").sum() #1745
none_count
# Out:
# np.int64(1745)

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley             2711
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1413
# Garage Type        156
# Garage Yr Blt      158
# Garage Finish      158
# Garage Cars          1
# Garage Area          1
# Garage Qual        158
# Garage Cond        158
# Pool QC           2894
# Fence             2335
# Misc Feature      2801
# dtype: int64

# %%
df["Bsmt Qual"].value_counts(dropna=False)
# Out:
# Bsmt Qual
# TA     1282
# Gd     1204
# Ex      251
# Fa       88
# NaN      80
# Po        2
# Name: count, dtype: int64

# %%
df["Bsmt Cond"].value_counts(normalize=True)*100
# Out:
# Bsmt Cond
# TA    91.793421
# Gd     4.244782
# Fa     3.678811
# Po     0.176866
# Ex     0.106120
# Name: proportion, dtype: float64

# %%
nan_bsmt = df[df['Bsmt Qual'].isna()]

has_sf = nan_bsmt[nan_bsmt['Total Bsmt SF'] > 0]
no_sf = nan_bsmt[nan_bsmt['Total Bsmt SF'] == 0]
nan_sf = nan_bsmt[nan_bsmt['Total Bsmt SF'].isna()]

# %%
len(has_sf)
# Out:
# 0

# %%
len(no_sf)
# Out:
# 79

# %%
len(nan_sf)
# Out:
# 1

# %%
df["Bsmt Qual"].isna().sum()
# Out:
# np.int64(80)

# %%
df["Has Bsmt"] = df["Bsmt Qual"].notna().astype(int)

# %%
df["Bsmt Qual"] = df["Bsmt Qual"].fillna("None")

# %%
df["Bsmt Qual Encoded"] = encode.fit_transform(df["Bsmt Qual"])

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley             2711
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1413
# Garage Type        156
# Garage Yr Blt      158
# Garage Finish      158
# Garage Cars          1
# Garage Area          1
# Garage Qual        158
# Garage Cond        158
# Pool QC           2894
# Fence             2335
# Misc Feature      2801
# dtype: int64

# %%
df["Bsmt Cond"].value_counts(dropna=False)
# Out:
# Bsmt Cond
# TA     2595
# Gd      120
# Fa      104
# NaN      80
# Po        5
# Ex        3
# Name: count, dtype: int64

# %%
df["Bsmt Cond"].isna().sum()/len(df["Bsmt Cond"])*100
# Out:
# np.float64(2.7519779841761265)

# %%
df.groupby("Bsmt Cond")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# Bsmt Cond
# Gd    211499.208333
# Ex    195000.000000
# TA    183575.786513
# Po    124063.200000
# Fa    123315.480769
# Name: SalePrice, dtype: float64

# %%
nan_bsmt_cond = df[df["Bsmt Cond"].isna()]
has_sf_cond = nan_bsmt_cond[nan_bsmt_cond["Total Bsmt SF"]>0]
no_sf_cond = nan_bsmt_cond[nan_bsmt_cond["Total Bsmt SF"]==0]
nan_df_cond = nan_bsmt_cond[nan_bsmt_cond["Total Bsmt SF"].isna()]

# %%
len(has_sf_cond)
# Out:
# 0

# %%
len(no_sf_cond)
# Out:
# 79

# %%
len(nan_df_cond)
# Out:
# 1

# %%
df["Has Bsmt"] = df["Bsmt Cond"].notna().astype(int)

# %%
df["Bsmt Cond"] = df["Bsmt Cond"].fillna("None")

# %%
df["Bsmt Cond Encode"]=encode.fit_transform(df["Bsmt Cond"])

# %%
mystery_nan = df["Bsmt Cond"].isna() & (df["Total Bsmt SF"].isna())
df.loc[mystery_nan,"Total Bsmt SF"] == 0
# Out:
# Series([], Name: Total Bsmt SF, dtype: bool)

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley             2711
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1413
# Garage Type        156
# Garage Yr Blt      158
# Garage Finish      158
# Garage Cars          1
# Garage Area          1
# Garage Qual        158
# Garage Cond        158
# Pool QC           2894
# Fence             2335
# Misc Feature      2801
# dtype: int64

# %%
df["Bsmt Exposure"].value_counts(dropna=False)
# Out:
# Bsmt Exposure
# No     1888
# Av      414
# Gd      283
# Mn      239
# NaN      83
# Name: count, dtype: int64

# %%
df["Bsmt Exposure"].isna().sum()/len(df["Bsmt Exposure"])*100
# Out:
# np.float64(2.8551771585827312)

# %%
df.groupby("Bsmt Exposure")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# Bsmt Exposure
# Gd    266809.791519
# Av    206933.787440
# Mn    187559.100418
# No    163749.313559
# Name: SalePrice, dtype: float64

# %%
nan_bsmt_ex = df[df["Bsmt Exposure"].isna()]
has_sf_ex = nan_bsmt_ex[nan_bsmt_ex["Total Bsmt SF"]>0]
no_sf_ex = nan_bsmt_ex[nan_bsmt_ex["Total Bsmt SF"]==0]
nan_sf_ex = nan_bsmt_ex[nan_bsmt_ex["Total Bsmt SF"].isna()]

# %%
len(has_sf_ex)
# Out:
# 3

# %%
len(no_sf_ex)
# Out:
# 79

# %%
len(nan_sf_ex)
# Out:
# 1

# %%
df['Bsmt Exposure'] = df['Bsmt Exposure'].fillna('None')

# %%
df["Bsmt Exposure Encode"] = encode.fit_transform(df["Bsmt Exposure"])

# %%
mystery_row = df["Bsmt Exposure"].isna() & df["Total Bsmt SF"].isna()
df.loc[mystery_row,"Total Bsmt SF"] == 0
# Out:
# Series([], Name: Total Bsmt SF, dtype: bool)

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley             2711
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1413
# Garage Type        156
# Garage Yr Blt      158
# Garage Finish      158
# Garage Cars          1
# Garage Area          1
# Garage Qual        158
# Garage Cond        158
# Pool QC           2894
# Fence             2335
# Misc Feature      2801
# dtype: int64

# %%
df["BsmtFin Type 1"].value_counts(dropna=False)
# Out:
# BsmtFin Type 1
# GLQ    848
# Unf    840
# ALQ    429
# Rec    287
# BLQ    269
# LwQ    154
# NaN     80
# Name: count, dtype: int64

# %%
df["BsmtFin Type 1"].isna().sum()/len(df["BsmtFin Type 1"])*100
# Out:
# np.float64(2.7519779841761265)

# %%
df.groupby("BsmtFin Type 1")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# BsmtFin Type 1
# GLQ    236995.505896
# Unf    166852.459524
# ALQ    163012.920746
# LwQ    152191.077922
# BLQ    150084.182156
# Rec    142572.571429
# Name: SalePrice, dtype: float64

# %%
nan_Bsmt_Fin = df[df["BsmtFin Type 1"].isna()]

has_Bsmt_Fin_sf = nan_Bsmt_Fin[nan_Bsmt_Fin["BsmtFin SF 1"]>0]
no_Bsmt_Fin_sf = nan_Bsmt_Fin[nan_Bsmt_Fin["BsmtFin SF 1"] == 0]
nan_Bsmt_Fin_sf = nan_Bsmt_Fin[nan_Bsmt_Fin["BsmtFin SF 1"].isna()]

# %%
len(has_Bsmt_Fin_sf)
# Out:
# 0

# %%
len(no_Bsmt_Fin_sf)
# Out:
# 79

# %%
len(nan_Bsmt_Fin_sf)
# Out:
# 1

# %%
mystery_row_Fin_sf = df["BsmtFin Type 1"].isna() & df["BsmtFin SF 1"].isna()
df.loc[mystery_row_Fin_sf, "BsmtFin SF 1"] = 0

# %%
df["BsmtFin Type 1"] = df["BsmtFin Type 1"].fillna("None")

# %%
df["BsmtFin Type 1 Encode"] = encode.fit_transform(df["BsmtFin Type 1"])

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley             2711
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1413
# Garage Type        156
# Garage Yr Blt      158
# Garage Finish      158
# Garage Cars          1
# Garage Area          1
# Garage Qual        158
# Garage Cond        158
# Pool QC           2894
# Fence             2335
# Misc Feature      2801
# dtype: int64

# %%
df["BsmtFin Type 2"].value_counts(dropna=False)
# Out:
# BsmtFin Type 2
# Unf    2477
# Rec     106
# LwQ      89
# NaN      81
# BLQ      68
# ALQ      52
# GLQ      34
# Name: count, dtype: int64

# %%
nan_bsmt_Fin_2 = df[df["BsmtFin Type 2"].isna()]
has_Bsmt_Fin_sf_2 = nan_bsmt_Fin_2[nan_bsmt_Fin_2["BsmtFin SF 2"]>0]
no_Bsmt_Fin_sf_2 = nan_bsmt_Fin_2[nan_bsmt_Fin_2["BsmtFin SF 2"]==0]
nan_bsmt_Fin_sf_2 = nan_bsmt_Fin_2[nan_bsmt_Fin_2["BsmtFin SF 2"].isna()]

# %%
len(has_Bsmt_Fin_sf_2)
# Out:
# 1

# %%
len(no_Bsmt_Fin_sf_2)
# Out:
# 79

# %%
len(nan_bsmt_Fin_sf_2)
# Out:
# 1

# %%
mystery_nan_BsmtFin_Type_2 = df["BsmtFin Type 2"].isna() & df["BsmtFin SF 2"].isna()
df.loc[mystery_nan_BsmtFin_Type_2, "BsmtFin SF 2"] = 0

# %%
mask_BsmtFin_sf_2 = (df["BsmtFin Type 2"].isna()) & (df["BsmtFin SF 2"]>0)
df.loc[mask_BsmtFin_sf_2, "BsmtFin Type 2"] = "Unknown"

# %%
df["BsmtFin Type 2"] = df["BsmtFin Type 2"].fillna("None")

# %%
df["BsmtFin Type 2 Encode"] = encode.fit_transform(df["BsmtFin Type 2"])

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley             2711
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1413
# Garage Type        156
# Garage Yr Blt      158
# Garage Finish      158
# Garage Cars          1
# Garage Area          1
# Garage Qual        158
# Garage Cond        158
# Pool QC           2894
# Fence             2335
# Misc Feature      2801
# dtype: int64

# %%
df[df["Bsmt Unf SF"].isna()]
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1341   1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour  ... Has Pool Has Fence Has Misc Feature  \
# 1341   NaN       IR1          Lvl  ...        0         1                0
#
#      Mas Vnr Type Encode Has Bsmt Bsmt Qual Encoded Bsmt Cond Encode  \
# 1341                   3        0                 3                3
#
#      Bsmt Exposure Encode  BsmtFin Type 1 Encode  BsmtFin Type 2 Encode
# 1341                    4                      4                      4
#
# [1 rows x 93 columns]

# %%
mystery_Bsmt_nan = df[df["Bsmt Unf SF"].isna()]
mystery_Bsmt_nan[["Total Bsmt SF","Bsmt Qual","Bsmt Unf SF"]]
# Out:
#       Total Bsmt SF Bsmt Qual  Bsmt Unf SF
# 1341            NaN      None          NaN

# %%
df["Bsmt Unf SF"] = df["Bsmt Unf SF"].fillna(0)

# %%
df["Bsmt Unf SF"].describe()
# Out:
# count    2907.000000
# mean      557.786722
# std       439.099695
# min         0.000000
# 25%       218.000000
# 50%       463.000000
# 75%       798.500000
# max      2336.000000
# Name: Bsmt Unf SF, dtype: float64

# %%
df["Total Bsmt SF"] = df["Total Bsmt SF"].fillna("None")

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley             2711
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1413
# Garage Type        156
# Garage Yr Blt      158
# Garage Finish      158
# Garage Cars          1
# Garage Area          1
# Garage Qual        158
# Garage Cond        158
# Pool QC           2894
# Fence             2335
# Misc Feature      2801
# dtype: int64

# %%
df["Electrical"].value_counts(dropna=False)
# Out:
# Electrical
# SBrkr    2659
# FuseA     188
# FuseF      50
# FuseP       8
# NaN         1
# Mix         1
# Name: count, dtype: int64

# %%
df["Electrical"] = df["Electrical"].fillna(df["Electrical"].mode()[0])

# %%
df["Electrical"].value_counts(dropna=False)
# Out:
# Electrical
# SBrkr    2660
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: count, dtype: int64

# %%
df["Bsmt Full Bath"].value_counts(dropna=False)
# Out:
# Bsmt Full Bath
# 0.0    1694
# 1.0    1171
# 2.0      38
# 3.0       2
# NaN       2
# Name: count, dtype: int64

# %%
df["Bsmt Full Bath"].describe()
# Out:
# count    2905.000000
# mean        0.431325
# std         0.525044
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: Bsmt Full Bath, dtype: float64

# %%
nan_bsmt_fbath = df[df["Bsmt Full Bath"].isna()]
cols = ['Bsmt Full Bath', 'Total Bsmt SF', 'Bsmt Qual', 'Bsmt Cond', 'SalePrice']
nan_bsmt_fbath[cols]
# Out:
#       Bsmt Full Bath Total Bsmt SF Bsmt Qual Bsmt Cond  SalePrice
# 1341             NaN          None      None      None      79000
# 1497             NaN           0.0      None      None     284700

# %%
df["Bsmt Full Bath"] = df["Bsmt Full Bath"].fillna(0)

# %%
df["Bsmt Full Bath"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Bsmt Full Bath"].value_counts(dropna=False)
# Out:
# Bsmt Full Bath
# 0.0    1696
# 1.0    1171
# 2.0      38
# 3.0       2
# Name: count, dtype: int64

# %%
df["Bsmt Full Bath"].describe()
# Out:
# count    2907.000000
# mean        0.431029
# std         0.524985
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: Bsmt Full Bath, dtype: float64

# %%
df["Bsmt Half Bath"].isna().sum()
# Out:
# np.int64(2)

# %%
df["Bsmt Half Bath"].value_counts(dropna=False)
# Out:
# Bsmt Half Bath
# 0.0    2730
# 1.0     171
# 2.0       4
# NaN       2
# Name: count, dtype: int64

# %%
nan_Bsmt_hbath = df[df["Bsmt Half Bath"].isna()]
cols = ['Bsmt Half Bath', 'Total Bsmt SF', 'Bsmt Qual', 'Bsmt Cond', 'SalePrice']
nan_Bsmt_hbath[cols]
# Out:
#       Bsmt Half Bath Total Bsmt SF Bsmt Qual Bsmt Cond  SalePrice
# 1341             NaN          None      None      None      79000
# 1497             NaN           0.0      None      None     284700

# %%
df["Bsmt Half Bath"] = df["Bsmt Half Bath"].fillna(0)

# %%
df["Bsmt Half Bath"].value_counts(dropna=False)
# Out:
# Bsmt Half Bath
# 0.0    2732
# 1.0     171
# 2.0       4
# Name: count, dtype: int64

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley            2711
# Fireplace Qu     1413
# Garage Type       156
# Garage Yr Blt     158
# Garage Finish     158
# Garage Cars         1
# Garage Area         1
# Garage Qual       158
# Garage Cond       158
# Pool QC          2894
# Fence            2335
# Misc Feature     2801
# dtype: int64

# %%
df["Garage Type"].value_counts(dropna=False)
# Out:
# Garage Type
# Attchd     1712
# Detchd      782
# BuiltIn     183
# NaN         156
# Basment      36
# 2Types       23
# CarPort      15
# Name: count, dtype: int64

# %%
df["Garage Type"].isna().sum()/len(df["Garage Type"])*100
# Out:
# np.float64(5.366357069143446)

# %%
df.groupby("Garage Type")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# Garage Type
# BuiltIn    249937.224044
# Attchd     203340.859813
# 2Types     154639.130435
# Basment    150473.416667
# Detchd     132468.471867
# CarPort    105566.666667
# Name: SalePrice, dtype: float64

# %%
nan_garage = df[df["Garage Type"].isna()]
has_garage = nan_garage[nan_garage["Garage Area"]>0]
no_garage = nan_garage[nan_garage["Garage Area"]==0]
nan_data_garage = nan_garage[nan_garage["Garage Area"].isna()]

# %%
len(has_garage)
# Out:
# 0

# %%
len(no_garage)
# Out:
# 156

# %%
len(nan_data_garage)
# Out:
# 0

# %%
df["Has Garage"] = df["Garage Type"].notna().astype(int)
df["Garage Type"] = df["Garage Type"].fillna("None")

# %%
df["Garage Type Encode"] = encode.fit_transform(df["Garage Type"])

# %%
# df.drop(columns="Garage Type",inplace=True)

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley            2711
# Fireplace Qu     1413
# Garage Yr Blt     158
# Garage Finish     158
# Garage Cars         1
# Garage Area         1
# Garage Qual       158
# Garage Cond       158
# Pool QC          2894
# Fence            2335
# Misc Feature     2801
# dtype: int64

# %%
df["Fireplace Qu"].value_counts(dropna=False)
# Out:
# Fireplace Qu
# NaN    1413
# Gd      735
# TA      595
# Fa       75
# Po       46
# Ex       43
# Name: count, dtype: int64

# %%
df["Fireplace Qu"].isna().sum()/len(df["Fireplace Qu"])*100
# Out:
# np.float64(48.60681114551084)

# %%
df.groupby("Fireplace Qu")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# Fireplace Qu
# Ex    344432.325581
# Gd    230920.340136
# TA    204560.813445
# Fa    166759.266667
# Po    141959.413043
# Name: SalePrice, dtype: float64

# %%
df["Fireplaces"]
# Out:
# 0       2
# 1       0
# 2       0
# 3       2
# 4       1
#        ..
# 2925    0
# 2926    0
# 2927    0
# 2928    1
# 2929    1
# Name: Fireplaces, Length: 2907, dtype: int64

# %%
nan_fire_place = df[df["Fireplace Qu"].isna()]
has_fp = nan_fire_place[nan_fire_place["Fireplaces"]>0]
no_fp = nan_fire_place[nan_fire_place["Fireplaces"]==0]
nan_fp = nan_fire_place[nan_fire_place["Fireplaces"].isna()]

# %%
len(has_fp)
# Out:
# 0

# %%
len(no_fp)
# Out:
# 1413

# %%
len(nan_fp)
# Out:
# 0

# %%
df["Has FirePlace"] = df["Fireplace Qu"].notna().astype(int)
df["Fireplace Qu"] = df["Fireplace Qu"].fillna("None")

# %%
df["Fireplace Qu Encode"] = encode.fit_transform(df["Fireplace Qu"])

# %%
# df.drop(columns="Fireplace Qu", inplace=True)

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley            2711
# Garage Yr Blt     158
# Garage Finish     158
# Garage Cars         1
# Garage Area         1
# Garage Qual       158
# Garage Cond       158
# Pool QC          2894
# Fence            2335
# Misc Feature     2801
# dtype: int64

# %%
df["Garage Yr Blt"].value_counts(dropna=False)
# Out:
# Garage Yr Blt
# NaN       158
# 2005.0    141
# 2006.0    112
# 2007.0    108
# 2004.0     99
#          ...
# 1908.0      1
# 1895.0      1
# 1933.0      1
# 1943.0      1
# 1919.0      1
# Name: count, Length: 103, dtype: int64

# %%
nan_garage_yr = df[df["Garage Yr Blt"].isna()]
has_area = nan_garage_yr[nan_garage_yr["Garage Area"]>0]
no_area = nan_garage_yr[nan_garage_yr["Garage Area"]==0]
nan_area = nan_garage_yr[nan_garage_yr["Garage Area"].isna()]

# %%
len(has_area)
# Out:
# 1

# %%
len(no_area)
# Out:
# 156

# %%
len(nan_area)
# Out:
# 1

# %%
mask_unknown = df['Garage Yr Blt'].isna() & (df['Garage Area'] > 0)
df.loc[mask_unknown, 'Garage Yr Blt'] = df.loc[mask_unknown, 'Year Built']#has Area 
mask_unknown.sum()
# Out:
# np.int64(1)

# %%
mask_nan_area_garage_row = df["Garage Yr Blt"].isna() & df["Garage Area"].isna()
df.loc[mask_nan_area_garage_row, "Garage Area"] = 0

# %%
df["Garage Yr Blt"] = df["Garage Yr Blt"].fillna(0)

# %%
df["Garage Yr Blt"].isna().sum()
# Out:
# np.int64(0)

# %%
df. isna().sum()[df.isna().sum()>0]
# Out:
# Alley            2711
# Garage Finish     158
# Garage Cars         1
# Garage Qual       158
# Garage Cond       158
# Pool QC          2894
# Fence            2335
# Misc Feature     2801
# dtype: int64

# %%
df["Garage Finish"].value_counts(dropna=False)
# Out:
# Garage Finish
# Unf    1229
# RFn     804
# Fin     716
# NaN     158
# Name: count, dtype: int64

# %%
df.groupby("Garage Finish")["SalePrice"].mean().sort_values(ascending=False)
# Out:
# Garage Finish
# Fin    239655.371508
# RFn    202351.781095
# Unf    141098.995118
# Name: SalePrice, dtype: float64

# %%
nan_garage_f = df[df["Garage Finish"].isna()]
has_area_g = nan_garage_f[nan_garage_f["Garage Area"]>0]
no_area_g = nan_garage_f[nan_garage_f["Garage Area"]==0]
nan_area_g = nan_garage_f[nan_garage_f["Garage Area"].isna()]

# %%
len(has_area_g)
# Out:
# 1

# %%
len(no_area_g)
# Out:
# 157

# %%
len(nan_area_g)
# Out:
# 0

# %%
mask_has_area_g = df["Garage Finish"].isna() & (df["Garage Area"] >0)
df.loc[mask_has_area_g, "Garage Finish"] = "Unknown"

# %%
df["Garage Finish"] = df["Garage Finish"].fillna("None")

# %%
df["Garage Finish"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Garage Qual"].value_counts(dropna=False)
# Out:
# Garage Qual
# TA     2593
# NaN     158
# Fa      124
# Gd       24
# Po        5
# Ex        3
# Name: count, dtype: int64

# %%
nan_garage_q = df[df["Garage Qual"].isna()]
has_garage_q = nan_garage_q[nan_garage_q["Garage Area"]>0]
no_garage_q = nan_garage_q[nan_garage_q["Garage Area"]==0]
nan_garage_area_q = nan_garage_q[nan_garage_q["Garage Area"].isna()]

# %%
len(has_garage_q)
# Out:
# 1

# %%
len(no_garage_q)
# Out:
# 157

# %%
len(nan_garage_area_q)
# Out:
# 0

# %%
mask_has_area_q = df["Garage Qual"].isna() & (df["Garage Area"]>0)
df.loc[mask_has_area_q, "Garage Qual"] = "Unknown"

# %%
df["Garage Qual"] = df["Garage Qual"].fillna("None")

# %%
df["Garage Qual"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Garage Cond"].value_counts(dropna=False)
# Out:
# Garage Cond
# TA     2643
# NaN     158
# Fa       74
# Gd       15
# Po       14
# Ex        3
# Name: count, dtype: int64

# %%
df.groupby("Garage Cond")["SalePrice"].mean().sort_index(ascending=False)
# Out:
# Garage Cond
# TA    187335.050700
# Po     94850.000000
# Gd    194058.000000
# Fa    107492.351351
# Ex    125000.000000
# Name: SalePrice, dtype: float64

# %%
nan_garage_c = df[df["Garage Cond"].isna()]
has_area_c = nan_garage_c[nan_garage_c["Garage Area"]>0]
no_area_c = nan_garage_c[nan_garage_c["Garage Area"]==0]
nan_area_c = nan_garage_c[nan_garage_c["Garage Area"].isna()]

# %%
len(has_area_c)
# Out:
# 1

# %%
len(no_area_c)
# Out:
# 157

# %%
len(nan_area_c)
# Out:
# 0

# %%
mask_nan_area_c = df["Garage Cond"].isna() & (df["Garage Area"]>0)
df.loc[mask_nan_area_c, "Garage Cond"] = "Unknown"

# %%
df["Garage Cond"] = df["Garage Cond"].fillna("None")

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley           2711
# Garage Cars        1
# Pool QC         2894
# Fence           2335
# Misc Feature    2801
# dtype: int64

# %%
df["Garage Cars"].value_counts(dropna=False)
# Out:
# Garage Cars
# 2.0    1585
# 1.0     778
# 3.0     370
# 0.0     156
# 4.0      16
# 5.0       1
# NaN       1
# Name: count, dtype: int64

# %%
nan_garage_cars = df[df['Garage Cars'].isna()]
nan_garage_cars[["Garage Cars","Garage Area", "Garage Type","Garage Yr Blt","SalePrice"]]
# Out:
#       Garage Cars  Garage Area Garage Type  Garage Yr Blt  SalePrice
# 2236          NaN          0.0      Detchd            0.0     150909

# %%
df["Garage Cars"] = df["Garage Cars"].fillna(0)

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Alley           2711
# Pool QC         2894
# Fence           2335
# Misc Feature    2801
# dtype: int64

# %%
cols_to_drop = ['Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 
                'BsmtFin Type 1', 'BsmtFin Type 2',
                'Garage Type', 'Garage Finish', 'Garage Qual',
                'Fireplace Qu','Alley', 'Pool QC', 'Fence',
                'Misc Feature', 'Garage Cond','Order', 'PID',
                "Bsmt Unf SF"]

# %%
df.drop(columns=cols_to_drop, inplace=True)

# %%
df.to_csv("AmesHousing_Cleaned.csv")
